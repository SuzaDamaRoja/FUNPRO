# %% [markdown]
# <a href="https://colab.research.google.com/github/SuzaDamaRoja/FUNPRO/blob/main/Clase_9_Listas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LISTAS
# Son tipos de datos que cumplen con tres caracterícas
# 1. Finita: Se puede contar cuántos elementos tiene la lista.
# 2. Homogénea: Sólo almacena un dato en específico
# 3. Ordenada o index: sabemos qué dato ocupa cada posición
#
# Sintaxis
# ```
# #Lista vacía
# lista=[]
# # Manual:
# flores=["rosa","azucena","amapola","jazmín"]
# ```

# %%
from IPython.display import Image, display
display(Image(url="https://media.licdn.com/dms/image/v2/C4E22AQG9LNjFv1Tpfg/feedshare-shrink_2048_1536/feedshare-shrink_2048_1536/0/1678636063061?e=2147483647&v=beta&t=FR0uQe_X0EZ371YEscoX_pYGZgKDEgXyFWmaxl-LxRE"))
# Out:
# <img src="https://media.licdn.com/dms/image/v2/C4E22AQG9LNjFv1Tpfg/feedshare-shrink_2048_1536/feedshare-shrink_2048_1536/0/1678636063061?e=2147483647&v=beta&t=FR0uQe_X0EZ371YEscoX_pYGZgKDEgXyFWmaxl-LxRE"/>

# %%
n=10
s=0
m=0
for e in range(n):
  sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
  s=sueldo+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
  sueldo=int(input(f"Ingrese el sueldo del trabajador {e+1}: "))
  if sueldo>prom: m=m+1
print(f"{m} trabajadores ganan más que el promedio")

#Problema: Ejercicio sin memoria.
# Out:
# Ingrese el sueldo del trabajador 1: 5000
# Ingrese el sueldo del trabajador 2: 10000
# Ingrese el sueldo del trabajador 3: 8000
# Ingrese el sueldo del trabajador 4: 9000
# Ingrese el sueldo del trabajador 5: 2000
# Ingrese el sueldo del trabajador 6: 1000
# Ingrese el sueldo del trabajador 7: 500
# Ingrese el sueldo del trabajador 8: 7000
# Ingrese el sueldo del trabajador 9: 8000
# Ingrese el sueldo del trabajador 10: 80000
# El sueldo promedio de la empresa es: 13050.0
# Ingrese el sueldo del trabajador 1: 1000
# Ingrese el sueldo del trabajador 2: 500
# Ingrese el sueldo del trabajador 3: 1000
# Ingrese el sueldo del trabajador 4: 5000
# Ingrese el sueldo del trabajador 5: 8000
# Ingrese el sueldo del trabajador 6: 80000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2979936015.py in <cell line: 0>()
#       8 for e in range(n):
# ...

# %%
s1=1000
s2=5000
s3=10000
s4=1000
s5=10000
s6=7000
s7=10000
s8=80000
s9=1000
s10=10000
prom=(s1+s2+s3+s4+s5+s6+s7+s8+s9+s10)
#Problema: mucha info. Yo no me voy a poner a hacer 40 variables 😑

# %%
n=10
s=0
m=0
sueldo=[]
for e in range(n):
  sueldo.append(int(input(f"Ingrese el sueldo del trabajador {e+1}: ")))
  s=sueldo[e]+s #acumulador
prom=s/n
print(f"El sueldo promedio de la empresa es: {prom}")
for e in range(n):
  if sueldo[e]>prom: m=m+1
print(f"{m} trabajadores ganan más que el promedio")
# Out:
# Ingrese el sueldo del trabajador 1: 10000
# Ingrese el sueldo del trabajador 2: 2000
# Ingrese el sueldo del trabajador 3: 5000
# Ingrese el sueldo del trabajador 4: 70000
# Ingrese el sueldo del trabajador 5: 82000
# Ingrese el sueldo del trabajador 6: 1000
# Ingrese el sueldo del trabajador 7: 40000
# Ingrese el sueldo del trabajador 8: 1000
# Ingrese el sueldo del trabajador 9: 5000
# Ingrese el sueldo del trabajador 10: 1000000
# El sueldo promedio de la empresa es: 121600.0
# 1 trabajadores ganan más que el promedio
